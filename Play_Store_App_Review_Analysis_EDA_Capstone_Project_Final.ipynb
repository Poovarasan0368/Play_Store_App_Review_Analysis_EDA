# %% [markdown]
# <a href="https://colab.research.google.com/github/Poovarasan0368/Play-Store-App-Review-Analysis-EDA/blob/main/Play_Store_App_Review_Analysis_EDA_Capstone_Project_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><u> Project Title : Play Store App Review Analysis EDA </u></b>

# %% [markdown]
# ##**Problem Description**
#
# **The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps. Explore and analyze the data to discover key factors responsible for app engagement and success.**

# %% [markdown]
# ##![image.png](https://i.pinimg.com/originals/60/a8/b5/60a8b504a19449659ac8e41d3fb807a4.gif)

# %% [markdown]
# # **Introduction**

# %% [markdown]
# Google Play Store or formerly Android Market, is a digital distribution service developed and operated by Google. It is an official apps store that provides variety content such as apps, books, magazines, music, movies and television programs. It serves an as platform to allow users with 'Google certified' Android operating system devices to donwload applications developed and published on the platform either with a charge or free of cost. With the rapidly growth of Android devices and apps, it would be interesting to perform data analysis on the data to obtain valuable insights.
#
# The tools that are going to be used for this EDA would be numpy, pandas, matplotlib and seaborn which I have learnt from the course.

# %% [markdown]
# # **Google PlayStore Dataset Analysis**

# %% [markdown]
# **In this Notebook, we are going to analyse the dataset (taken from almabetter cappstone) of all the Apps in the Google Play Store**
#
# **The series of steps followed are :**
#
#     1. Importing Packages
#     2. Reading Data
#     3. Explore the structure of the Datasets
#     4. Cleaning the Given Datasets
#     5. Convert the Installs, Price and Size columns for EDA analysis
#     6. Preparing User_review data frame for EDA
#     7. Exploratory Data Analysis (EDA)
#     8. ED Analysis for Paid Apps
#     9. Data Visualization of user_review Dataframe

# %% [markdown]
# ## **Let's take a look at the data, which consists of two files:**
#
# play_store_data.csv: contains all the details of the applications on Google Play. There are 13 features that describe a given app.
#
# user_reviews.csv: contains 100 reviews for each app, most helpful first. The text in each review has been pre-processed and attributed with three new features: Sentiment (Positive, Negative or Neutral), Sentiment Polarity and Sentiment Subjectivity.

# %% [markdown]
# # **1. Importing Packages**

# %%
# Importing Packages what we needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Mounting Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **2. Reading Data**

# %%
# Reding Both Data Frame

play_store = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/play store/Play Store Data.csv')
Df_review = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/play store/User Reviews.csv")

# %%
# head of the play_store dataframe 

play_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Tail of the Play_Store dataframe 

play_store.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# First 5 rows of Review Dataframe

Df_review.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# Last 5 rows of Review Dataframe

Df_review.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %% [markdown]
# # **3. Explore the structure of the Datasets**

# %%
# Finding the Data type and Non-null count of each coulmn

play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# finding the columns name 

play_store.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# finding the shape of Dataframe

play_store.shape
# Out:
# (10841, 13)

# %%
# counting the null_values present in each columns

def Null_values():
  Null_values = pd.DataFrame(index= play_store.columns)
  Null_values['Non Null counts'] = play_store.notnull().sum()
  Null_values['Null counts'] = play_store.isnull().sum()
  return Null_values

Null_values()
# Out:
#                 Non Null counts  Null counts
# App                       10841            0
# Category                  10841            0
# Rating                     9367         1474
# Reviews                   10841            0
# Size                      10841            0
# Installs                  10841            0
# Type                      10840            1
# Price                     10841            0
# Content Rating            10840            1
# Genres                    10841            0
# Last Updated              10841            0
# Current Ver               10833            8
# Android Ver               10838            3

# %% [markdown]
# **The above Dataframe show the Total counts of Null and Non Null values present in each calumns**

# %%
# counting the unique values present in each colunms

uniques_counts = pd.DataFrame(index= play_store.columns)
uniques_counts['Total_counts'] = play_store.count()
uniques_counts['uniques_counts'] = play_store.nunique()

uniques_counts
# Out:
#                 Total_counts  uniques_counts
# App                    10841            9660
# Category               10841              34
# Rating                  9367              40
# Reviews                10841            6002
# Size                   10841             462
# Installs               10841              22
# Type                   10840               3
# Price                  10841              93
# Content Rating         10840               6
# Genres                 10841             120
# Last Updated           10841            1378
# Current Ver            10833            2832
# Android Ver            10838              33

# %% [markdown]
# **The above Dataframe show the Total counts of unique values present in each calumns**

# %%
# counting the duplicated values present in each colunms

def Duplicated_values():
  
  temp = [play_store['App'].duplicated().sum() , play_store['Category'].duplicated().sum(), play_store['Rating'].duplicated().sum(),
          play_store['Reviews'].duplicated().sum(), play_store['Size'].duplicated().sum(), play_store['Installs'].duplicated().sum(),
          play_store['Type'].duplicated().sum(), play_store['Price'].duplicated().sum(), play_store['Content Rating'].duplicated().sum(), 
          play_store['Genres'].duplicated().sum(), play_store['Last Updated'].duplicated().sum(), play_store['Current Ver'].duplicated().sum(), 
          play_store['Android Ver'].duplicated().sum()]

  Duplicated_values = pd.DataFrame(temp,index = (play_store.columns), columns = ['Duplicated values'])
  Duplicated_values['Total_counts'] = play_store.count()
  return Duplicated_values

Duplicated_values()
# Out:
#                 Duplicated values  Total_counts
# App                          1181         10841
# Category                    10807         10841
# Rating                      10800          9367
# Reviews                      4839         10841
# Size                        10379         10841
# Installs                    10819         10841
# Type                        10837         10840
# Price                       10748         10841
# Content Rating              10834         10840
# Genres                      10721         10841
# Last Updated                 9463         10841
# Current Ver                  8008         10833
# Android Ver                 10807         10838

# %% [markdown]
# **The above Dataframe show the Total counts of duplicated values present in each calumns**

# %% [markdown]
# # **4. Cleaning the Given Datasets**

# %%
# Unique Values in rating columns 

print(play_store['Rating'].unique())
print(play_store.shape)

# Removing outlyers from rating columns

play_store.drop(play_store[play_store['Rating'] == 19.0].index, inplace = True)
print(play_store.shape)
# Out:
# [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   1.9  2.5  2.8  2.7  1.
#   2.9  2.3  2.2  1.7  2.   1.8  2.4  1.6  2.1  1.4  1.5  1.2 19. ]
# (10841, 13)
# (10840, 13)

# %%
# Removing the Null values 

play_store.dropna(inplace=True)
Null_values()
# Out:
#                 Non Null counts  Null counts
# App                        9360            0
# Category                   9360            0
# Rating                     9360            0
# Reviews                    9360            0
# Size                       9360            0
# Installs                   9360            0
# Type                       9360            0
# Price                      9360            0
# Content Rating             9360            0
# Genres                     9360            0
# Last Updated               9360            0
# Current Ver                9360            0
# Android Ver                9360            0

# %%
# Removing Duplicate Values from App Columns 

play_store.drop_duplicates(subset= 'App', inplace=True)
Duplicated_values()
# Out:
#                 Duplicated values  Total_counts
# App                             0          8190
# Category                     8157          8190
# Rating                       8151          8190
# Reviews                      2871          8190
# Size                         7777          8190
# Installs                     8171          8190
# Type                         8188          8190
# Price                        8117          8190
# Content Rating               8184          8190
# Genres                       8076          8190
# Last Updated                 6891          8190
# Current Ver                  5566          8190
# Android Ver                  8159          8190

# %% [markdown]
# # **5. Convert the Installs, Price and Size columns for EDA analysis**

# %%
# Removing '+' and ',' Symbol from Insalls Columns

play_store['Installs'] = play_store['Installs'].str.replace('+','').str.replace(',','')
play_store.tail()
# Out:
#                                                  App             Category  \
# 10834                                  FR Calculator               FAMILY
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size  Installs  Type Price  \
# 10834     4.0       7                2.6M       500  Free     0
# 10836     4.5      38                 53M      5000  Free     0
# 10837     5.0       4                3.6M       100  Free     0
# 10839     4.5     114  Varies with device      1000  Free     0
# 10840     4.5  398307                 19M  10000000  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# Removing '$' Symbol From price columns
play_store['Price'] = play_store['Price'].apply(lambda x : str(x).lstrip('$'))

# %%
# Creating function for to convert Megabyte to kilobytes and Remove M from size column

def converting_size(i):

  if i[-1] == 'M':
      M = float(i[0:-1])
      M = M*1024
      return M
  else :
      return i

# %%
# using the created coverting_size function
play_store['Size'] = play_store['Size'].apply(lambda x :converting_size(x))

# %%
# Removing 'k' from Size column
play_store['Size'] = play_store['Size'].apply(lambda x : str(x).rstrip('k'))

# converting 'Varies with device' to '0' from Size column
play_store['Size'] = play_store['Size'].apply(lambda x : 0 if str(x) == 'Varies with device' else x )

# converting Size data type into numeric data type
play_store['Size'] = pd.to_numeric(play_store['Size'])

# converting Size into Megabytes
play_store['Size'] = play_store['Size'].apply(lambda x : x/1024)

# check play_store data frame 
play_store.reset_index().drop('index', axis=1)
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 8185                                      FR Calculator               FAMILY
# 8186                                   Sya9a Maroc - FR               FAMILY
# 8187                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 8188                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 8189      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# converting the data frame columns to appropirate data type

play_store['Installs'] = pd.to_numeric(play_store['Installs'])
play_store['Rating'] = pd.to_numeric(play_store['Rating'])
play_store['Reviews'] = pd.to_numeric(play_store['Reviews'])
play_store['Size'] = pd.to_numeric(play_store['Size'])
play_store['Price'] = pd.to_numeric(play_store['Price'])


play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8190 non-null   object
#  1   Category        8190 non-null   object
#  2   Rating          8190 non-null   float64
#  3   Reviews         8190 non-null   int64
#  4   Size            8190 non-null   float64
#  5   Installs        8190 non-null   int64
#  6   Type            8190 non-null   object
#  7   Price           8190 non-null   float64
#  8   Content Rating  8190 non-null   object
#  9   Genres          8190 non-null   object
#  10  Last Updated    8190 non-null   object
#  11  Current Ver     8190 non-null   object
#  12  Android Ver     8190 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 895.8+ KB

# %% [markdown]
# # **6. Preparing User_review data frame for EDA**

# %%
# Information about Df_Review Dataframe

print(Df_review.info())
print('\n \n')
Df_review.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB
# None
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# ...

# %%
# Number of Nan, Not NaN and Unique values in data frame

def Detailed_Data_Nan():
  Detailed_Data = pd.DataFrame(index = Df_review.columns)
  Detailed_Data['null values'] = Df_review.isna().sum()
  Detailed_Data['not null values'] = Df_review.notna().sum()
  Detailed_Data['unique values'] = Df_review.nunique()
  Detailed_Data['% of null values'] = (Df_review.isna().mean()*100).round(2)
  Detailed_Data['% of not null values'] = (Df_review.notna().mean()*100).round(2)

  return Detailed_Data

Detailed_Data_Nan()
# Out:
#                         null values  not null values  unique values  \
# App                               0            64295           1074
# Translated_Review             26868            37427          27994
# Sentiment                     26863            37432              3
# Sentiment_Polarity            26863            37432           5410
# Sentiment_Subjectivity        26863            37432           4474
#
#                         % of null values  % of not null values
# App                                 0.00                100.00
# Translated_Review                  41.79                 58.21
# Sentiment                          41.78                 58.22
# Sentiment_Polarity                 41.78                 58.22
# Sentiment_Subjectivity             41.78                 58.22

# %%
# visualizing Nan,Unique and Not_Nan values 

def Detailed_visual_Data_Nan():
  Detailed_visual_Data = pd.DataFrame(index = Df_review.columns)
  Detailed_visual_Data['null values'] = Df_review.isna().sum()
  Detailed_visual_Data['not null values'] = Df_review.notna().sum()
  Detailed_visual_Data['unique values'] = Df_review.nunique()

  percentage_of_Nan = pd.DataFrame(index = Df_review.columns)
  percentage_of_Nan['% of null values'] = (Df_review.isna().mean()*100).round(2)
  percentage_of_Nan['% of not null values'] = (Df_review.notna().mean()*100).round(2)

  plt.rcParams['figure.figsize'] = (10, 4)
  return Detailed_visual_Data.plot(kind='bar'), percentage_of_Nan.plot(kind='bar')

Detailed_visual_Data_Nan()
# Out:
# (<AxesSubplot:>, <AxesSubplot:>)

# %%
# Handling Nan values in the User Review
Df_review.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Removing Nan values From user reviews
Df_review = Df_review.dropna()
Df_review.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
# Merge Two Data frames  
Df_review = play_store.merge(Df_review, on = "App")
Df_review.head()
# Out:
#                    App        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
#
#    Price Content Rating                     Genres      Last Updated  \
# 0    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# ...

# %% [markdown]
# # **7. Exploratory Data Analysis (EDA)**

# %%
# Find App Counts of each Type
play_store = play_store[(play_store["Type"] != "0")]
Count_Type = play_store.groupby(by=play_store['Type'])['Type'].count().sort_values(ascending = False)
Count_Type.head()
# Out:
# Type
# Free    7588
# Paid     602
# Name: Type, dtype: int64

# %%
# Find App Counts in each Category
Count_Category = play_store.groupby(by=play_store['Category'])['Category'].count().sort_values(ascending = False)
Count_Category
# Out:
# Category
# FAMILY                 1607
# GAME                    912
# TOOLS                   717
# FINANCE                 302
# LIFESTYLE               301
# PRODUCTIVITY            301
# PERSONALIZATION         296
# MEDICAL                 290
# BUSINESS                263
# PHOTOGRAPHY             263
# SPORTS                  260
# COMMUNICATION           256
# HEALTH_AND_FITNESS      244
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           148
# DATING                  134
# EDUCATION               118
# MAPS_AND_NAVIGATION     118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           94
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       63
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           60
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# ...

# %%
# Find App Counts of each content_rating
Count_content_rating = play_store.groupby(by=play_store['Content Rating'])['Content Rating'].count().sort_values(ascending = False)
Count_content_rating.head()
# Out:
# Content Rating
# Everyone           6612
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Name: Content Rating, dtype: int64

# %%
# Find App Counts of each generes
Count_generes = play_store.groupby(by=play_store['Genres'])['Genres'].count().sort_values(ascending = False)
Count_generes.head()
# Out:
# Genres
# Tools            716
# Entertainment    471
# Education        429
# Finance          302
# Productivity     301
# Name: Genres, dtype: int64

# %%
# Find distribution of rating  
distri_rating = play_store.groupby(by=play_store['Rating'])['Rating'].count().sort_values(ascending = False)
distri_rating.head()
# Out:
# Rating
# 4.3    897
# 4.4    894
# 4.5    847
# 4.2    809
# 4.6    683
# Name: Rating, dtype: int64

# %%
# Find distribution of Size  
distri_Size = play_store.groupby(by=play_store['Size'])['Size'].count().sort_values(ascending = False)
distri_Size.head()
# Out:
# Size
# 0.0     1169
# 14.0     148
# 12.0     146
# 11.0     143
# 13.0     143
# Name: Size, dtype: int64

# %%
# Find most available apps_android version on playstore
temp = play_store[(play_store['Android Ver'] != "Varies with device")]
Most_Avail_androver = play_store.groupby(by=temp['Android Ver'])['Android Ver'].count().sort_values(ascending = False)
Most_Avail_androver.head()
# Out:
# Android Ver
# 4.1 and up      1811
# 4.0.3 and up    1141
# 4.0 and up      1040
# 4.4 and up       713
# 2.3 and up       547
# Name: Android Ver, dtype: int64

# %%
# graphical presentation of App Counts in each Types

plt.rcParams['figure.figsize'] = [10,10]
plt.pie(x = play_store['Type'].value_counts(), labels=['Free','paid'], autopct='%1.1f%%', shadow=True, startangle=270,);
plt.title('App Counts percentage of Each Types', fontsize= 20 , y= 1.0);

# %% [markdown]
# **The chart above shows that 92% of Play Store applications are free and 8% are on sale.**

# %%
# graphical presentation of App Counts in each Category

plt.figure(figsize=(15,15))
plt.pie(play_store['Category'].value_counts(), labels=play_store['Category'].value_counts().index, autopct='%1.2f%%')
circle = plt.Circle( (0,0), 0.50, color='white')
k = plt.gcf()
k.gca().add_artist(circle)
plt.title(' Apps percentage in each category', fontsize= 20);

# %% [markdown]
# **Consequently, the dataset contains 33 categories in total.  The results above indicate that the majority of apps in the Play Store fall into the FAMILY & GAME category, while the least number of apps go into the EVENTS & BEAUTY category.**

# %%
# graphical presentation of App Counts in Content Rating

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [10,5]
sns.countplot(x='Content Rating',palette="rainbow", data=play_store);
plt.xlabel('Content Rating',fontsize=16)
plt.ylabel('counts',fontsize=16)
plt.title('Counts of each Content Rating', fontsize= 20 , y= 1.06)

plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **A majority of the applications in the play store are available for everyone to use. Other applications have different age limits for using it.**

# %%
# graphical presentation of App Counts in Genres

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [20,5]
sns.countplot(x='Genres',palette="rainbow", data=play_store);
plt.xlabel('Genres',fontsize=16)
plt.ylabel('counts',fontsize=16)
plt.title('Number of apps by Genres', fontsize= 20 , y= 1.06)

plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **According to the results above, the vast majority of apps in the Google Play Store belong into the Tools, Entertainment and education category.**

# %%
# graphical presentation of rating distribution 

sns.set_style("darkgrid")
plt.rcParamsDefault
a= sns.displot(x='Rating',palette="rainbow", data=play_store);
a.fig.suptitle('Distribution of rating', fontsize= 20 , y= 1.08)
plt.ylabel('Distribution',fontsize=16)
plt.xlabel('Rating',fontsize=16)


plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **If we divide the ratings into intervals, we can better represent the ratings. Here, the ratings can be categorised as follows:**
#
# * 4-5: Top rated
# * 3-4: Above average
# * 2-3: Average
# * 1-2: Below average

# %%
# graphical presentation of size distribution 

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [15,5];
sns.distplot(x=play_store['Size'], color="r");
plt.title('Distribution of Size', fontsize= 20 , y= 1.08);
plt.xlabel('Size',fontsize=16);
x = np.arange(0, 100, 3);
plt.xticks(x);
plt.show;

# %% [markdown]
# **The findings above show that most apps in the Google Play Store have sizes between 0 and 5.**

# %%
sns.set_style('dark')
plt.rcParams['figure.figsize'] = [20,5]
sns.countplot(x='Android Ver', palette='cubehelix',data=temp)
plt.ylabel('Count',fontsize=16)
plt.xlabel('Android Version',fontsize=16)
plt.title('The android version most avaiable on playstore', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **Most Google Play Store apps have an Android version of 4.1 or higher, based on the results above.**

# %% [markdown]
# ## **7.1. Pairplot for Size,Install,Review and Rating**

# %%
r = play_store['Rating']
s = play_store['Size']
i = play_store['Installs']
re = play_store['Reviews']
ty = play_store['Type']

sns.set_style('darkgrid')
sns.pairplot(pd.DataFrame(list(zip(r, s, np.log(i), np.log10(re), ty)),columns=['Rating','Size', 'Installs', 'Reviews', 'Type']), hue="Type", height=2.6)

# %% [markdown]
# ## **7.2. Type which mostly loved by many peoples ?**

# %%
# find Which type of app highly installed
Type_install = play_store.groupby(by=play_store['Type'])['Installs'].mean().sort_values(ascending = False)
Type_install
# Out:
# Type
# Free    9.891699e+06
# Paid    9.518352e+04
# Name: Installs, dtype: float64

# %%
# graphical prsentation of type of App which highly installed by most of pepoles

sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = [12,6]
sns.boxplot(x='Type', y='Installs', palette="gist_rainbow_r" ,data=play_store);
plt.xlabel('Type',fontsize=16)
plt.ylabel('Installs',fontsize=16)
plt.title('App Type Vs Installs', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=0);

# %% [markdown]
# **Free apps are installed more frequently than expensive apps, as was predicted.**

# %% [markdown]
# ## **7.3.How Category affects the installation ?**

# %%
# find Which catagory Apps had high installs ?
category_install = play_store.groupby(by=play_store['Category'])['Installs'].mean().sort_values(ascending = False)

# Top 5 category which had high installs 
category_install.head()
# Out:
# Category
# COMMUNICATION    4.311813e+07
# SOCIAL           2.703370e+07
# VIDEO_PLAYERS    2.653241e+07
# ENTERTAINMENT    2.072216e+07
# PRODUCTIVITY     1.924608e+07
# Name: Installs, dtype: float64

# %%
# graphical presentation of category which had high installs

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [20,5]
sns.boxenplot(x='Category', y='Installs',palette="gist_rainbow", data=play_store);
plt.xlabel('Category',fontsize=16)
plt.ylabel('Installs',fontsize=16)
plt.title('Category Vs Installs', fontsize= 20 , y= 1.06)

plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **From this, it can be observed that the most often installed applications fall into the categories of communication, social , video players, entertainment, and productivity.**

# %% [markdown]
# ## **7.4. How content Rating infulences Download ?**

# %%
 # Find Which content rating highly installed ?
content_rating_install = play_store.groupby(by=play_store['Content Rating'])['Installs'].mean().sort_values(ascending = False)

# Top 2 category which had high installs 
content_rating_install.head(2)
# Out:
# Content Rating
# Teen            1.807791e+07
# Everyone 10+    1.316769e+07
# Name: Installs, dtype: float64

# %%
# graphical prsentation of content rating which highly installed

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [16,5]
sns.lineplot(x='Content Rating', y='Installs', color = 'green' , data=play_store);
plt.xlabel('Content Rating',fontsize=16)
plt.ylabel('Installs',fontsize=16)
plt.title('Content Rating Vs Installs', fontsize= 20 , y= 1.06)

plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=0);

# %% [markdown]
# **Installed are any age-appropriate apps other than those marked "Adults only 18+" and "Unrated." The 'Teen' and 'Everyone 10+' applications, on the other hand, have been downloaded more than 30 million times.**

# %% [markdown]
# ## **7.5. How generes increses download of Apps ?**

# %%
# find Which type of genere mostly installed by peoples 
genere_install = play_store.groupby(by=play_store['Genres'])['Installs'].mean().sort_values(ascending = False)

# the most install top 10 generes
genere_install.head(10)
# Out:
# Genres
# Communication                     4.311813e+07
# Social                            2.703370e+07
# Video Players & Editors           2.664488e+07
# Arcade                            2.195952e+07
# Adventure;Action & Adventure      2.123000e+07
# Casual                            1.944445e+07
# Productivity                      1.924608e+07
# Puzzle;Action & Adventure         1.836667e+07
# Photography                       1.767735e+07
# Educational;Action & Adventure    1.701667e+07
# Name: Installs, dtype: float64

# %%
# graphical prsentation of type of genere mostly installed by peoples

sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = [21,5]
sns.barplot(x='Genres', y='Installs',data=play_store);
plt.xlabel('Genres',fontsize=16)
plt.ylabel('Installs',fontsize=16)
plt.title('Genres Vs Installs', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation= 90);

# %% [markdown]
# **Apps in the genre "Communication" do incredibly well. The following genres are also worth developing an app for:**
#
# * Social
# * Video Players & Editors
# * Arcade
# * Adventure; Action & Adventure
# * Casual
# * Productivity
# * Puzzle; Action & Adventure
# * Photography
# * Educational; Action & Adventure

# %% [markdown]
# ## **7.6. Which rating mostly attracts peoples ?**

# %%
# find app which is mostly download by peoples based on the rating 
Rating_install = play_store.groupby(by=play_store['Rating'])['Installs'].mean().sort_values(ascending = False)
Rating_install.head()
# Out:
# Rating
# 4.3    1.789993e+07
# 4.5    1.499198e+07
# 4.4    1.496725e+07
# 4.2    1.115702e+07
# 4.6    9.162858e+06
# Name: Installs, dtype: float64

# %%
# graphical prsentation app which is mostly download by peoples based on the rating 

sns.set_style('white')
plt.rcParams['figure.figsize'] = [8,8]
sns.stripplot(x ="Installs", y ="Rating",data=play_store);
plt.xlabel('Installs',fontsize=16)
plt.ylabel('Rating',fontsize=16)
plt.title('Rating Vs Installs', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation= 90);

# %% [markdown]
# **The conclusion reached from this is that apps with ratings between 4.2 and 4.5 are downloaded more than 40 million times, while those with ratings between 3.9 and 4.2 as well as 4.6 are downloaded between 1 million and 2 million times. The number of installations for all the others is less than one million.**

# %% [markdown]
# ## **7.7. Which Size of the app mostly downloaded by many peoples ?**

# %%
# find Which Size of App mostly installed by peoples 
Size_install = play_store.groupby(by=play_store['Size'])['Installs'].mean().sort_values(ascending = False)

# the most install top 10 Size
Size_install.head(6)
# Out:
# Size
# 76.0    7.743644e+07
# 74.0    5.701005e+07
# 70.0    3.965860e+07
# 0.0     3.739861e+07
# 75.0    2.916833e+07
# 97.0    2.841918e+07
# Name: Installs, dtype: float64

# %%
# graphical prsentation app which is mostly download by peoples based on the rating 

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = [20,5]
sns.lineplot(x="Size", y="Installs", color = 'purple', data=play_store, size = 10)
plt.ylabel('Installs',fontsize=16)
plt.xlabel('Size(mb)',fontsize=16)
plt.title('Size Vs Installs', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
x = np.arange(0, 100, 5)
plt.xticks(x)
plt.xticks(rotation=0);

# %% [markdown]
# **More than 1 million people have downloaded apps between 72 and 76 Mb in size, followed by 0.5 to 1 million people who have downloaded apps between 61, 70, 97, and 98 Mb in size. Less than 0.5 million of the remaining apps have been downloaded, and others have never been downloaded at all.**

# %% [markdown]
# ## **7.8. Android_version which highly Downloded by many peoples?**

# %%
# find most using android version 
temp = play_store[(play_store['Android Ver'] != "Varies with device")]
Most_Using_androver = temp.groupby(by=temp['Android Ver'])['Installs'].mean().sort_values(ascending = False)

# the android verison used by most of the peoples
Most_Using_androver.head()
# Out:
# Android Ver
# 4.1 - 7.1.1      1.000000e+08
# 7.1 and up       3.368333e+07
# 2.0.1 and up     1.443858e+07
# 5.0 - 8.0        1.000000e+07
# 4.0.3 - 7.1.1    7.500000e+06
# Name: Installs, dtype: float64

# %%
# graphical prsentation of android verison used by most of the peoples 

sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = [20,5]
sns.pointplot(x="Android Ver", y="Installs", color = 'yellow', data=temp, size = 10)
plt.ylabel('Installs',fontsize=16)
plt.xlabel('Android Ver',fontsize=16)
plt.title('Android Ver Vs Installs', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **More than 100 million apps have been downloaded for Android versions 4.1-7.1.1, followed by 33 million downloads for Android versions 7.1 and higher. Less than one million people download the remaining apps, and some people never download any at all.**

# %% [markdown]
# # **8. ED Analysis for Paid Apps**

# %% [markdown]
# ## **8.1 Extracting Paid Apps from the DataFrame**

# %%
# Extract Paid Apps 

Paid_App = play_store[(play_store["Type"] == "Paid")].reset_index()
Paid_App
# Out:
#      index                                            App            Category  \
# 0      234  TurboScan: scan documents and receipts in PDF            BUSINESS
# 1      235                 Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 2      427                             Puffin Browser Pro       COMMUNICATION
# 3      476                      Moco+ - Chat, Meet People              DATING
# 4      477                                     Calculator              DATING
# ..     ...                                            ...                 ...
# 597  10690                                       FO Bixby     PERSONALIZATION
# 598  10697                                        Mu.F.O.                GAME
# 599  10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 600  10782                        Trine 2: Complete Story                GAME
# 601  10785                                   sugar, sugar              FAMILY
#
# ...

# %% [markdown]
# **The apps that fall under the paid category are removed separately and considered paid apps for paid app analysis.**

# %% [markdown]
# ## **8.2 Pairplot for Size,Install,Price,Review and Rating**

# %%
r = Paid_App['Rating']
s = Paid_App['Size']
i = Paid_App['Installs']
re = Paid_App['Reviews']
price =Paid_App['Price']

sns.set_style('darkgrid')
sns.pairplot(pd.DataFrame(list(zip(r, s, np.log(i), np.log10(re), price)),
                            columns=['Rating','Size', 'Installs', 'Reviews', 'Price']), height=2.6)

# %% [markdown]
# ## **8.3 From Which catagory most of the users Downloading Paid Apps ?**

# %%
# find Which catagory paid apps had high install ?
Paid_category_install = Paid_App.groupby(by=Paid_App['Category'])['Installs'].mean().sort_values(ascending = False)

# Top 5 category which had high installs 
Paid_category_install.head()
# Out:
# Category
# GAME           276306.078947
# EDUCATION      150500.000000
# FAMILY         134619.803922
# PHOTOGRAPHY    125234.666667
# WEATHER        115928.571429
# Name: Installs, dtype: float64

# %%
# graphical prsentation of category which had high installs

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [20,5]
sns.barplot(x='Category', y='Installs',palette="gist_rainbow", data=Paid_App);
plt.xlabel('Category',fontsize=16)
plt.ylabel('Installs',fontsize=16)
plt.title('Graphical prsentation of category which had high installs', fontsize= 20 , y= 1.06)

plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **The majority of consumers spend money to download games, educational apps, and family apps.**

# %% [markdown]
# ## **8.4 Find the content_rating highly installed by users ?**

# %%
 # find Which Paid content_rating highly installed ?
paid_content_rating_install = Paid_App.groupby(by=Paid_App['Content Rating'])['Installs'].mean().sort_values(ascending = False)

# Top 2 content_ratng which had high installs 
paid_content_rating_install.head(2)
# Out:
# Content Rating
# Mature 17+      754820.666667
# Everyone 10+    467887.096774
# Name: Installs, dtype: float64

# %%
# graphical prsentation of content rating which highly installed

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [16,5]
sns.lineplot(x='Content Rating', y='Installs', color = 'black' , data=Paid_App);
plt.xlabel('Content Rating',fontsize=16)
plt.ylabel('Installs',fontsize=16)
plt.title('graphical representation of the highly installed content rating', fontsize= 20 , y= 1.06)

plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=0);

# %% [markdown]
# **most paying users pay to download apps in the "Mature 17+"**

# %% [markdown]
# ## **8.5 The paid app mostly liked by users belongs to which genere ?**

# %%
# find Which type of paid genere mostly installed by peoples 
paid_genere_install = Paid_App.groupby(by=Paid_App['Genres'])['Installs'].mean().sort_values(ascending = False)

# the most installed top 10 generes
paid_genere_install.head(10)
# Out:
# Genres
# Arcade;Action & Adventure    3.370000e+06
# Card;Action & Adventure      1.000000e+06
# Action                       7.105104e+05
# Puzzle;Brain Games           5.500000e+05
# Sports;Action & Adventure    3.000000e+05
# Simulation;Education         3.000000e+05
# Strategy                     1.535000e+05
# Puzzle                       1.337850e+05
# Photography                  1.252347e+05
# Weather                      1.159286e+05
# Name: Installs, dtype: float64

# %%
# graphical prsentation of type of genere mostly installed by peoples

sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = [21,5]
sns.barplot(x='Genres', y='Installs',data=Paid_App);
plt.xlabel('Genres',fontsize=16)
plt.ylabel('Installs',fontsize=16)
plt.title('Graphical representation of the type of application that users frequently install', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation= 90);

# %% [markdown]
# **Arcade; Action & Adventure-themed apps are very popular. It's also worth while to create an app for the following genres:**
#
# * Sports;Action & Adventure
# * Card;Action & Adventure
# * Action
# * Puzzle;Brain Games

# %% [markdown]
# ## **8.6 Find the average rating which highly download by users ?**

# %%
# find paid app which is mostly download by peoples based on the rating 
Rating_install = Paid_App.groupby(by=Paid_App['Rating'])['Installs'].mean().sort_values(ascending = False)
Rating_install.head()
# Out:
# Rating
# 4.6    242721.052632
# 4.5    234367.424242
# 4.3    137491.836735
# 4.4    104926.470588
# 4.7     70718.200000
# Name: Installs, dtype: float64

# %%
# graphical prsentation app which is mostly download by peoples based on the rating 

sns.set_style('white')
plt.rcParams['figure.figsize'] = [8,8]
sns.regplot(y='Rating', x ='Installs',color = 'orange',data=Paid_App);
plt.xlabel('Installs',fontsize=16)
plt.ylabel('Rating',fontsize=16)
plt.title('Graphical presentation app that people tend to download based on ratings', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation= 0);

# %% [markdown]
# **Ratings of 4.5 and 4.6 did exceptionally well in the market. The majority of premium customers only downloaded apps based on these two ratings.**

# %% [markdown]
# ## **8.7 Find the Paid app which highly download my users based on the app size ?**

# %%
# find Which Size of paid pp mostly installed by peoples 
paid_Size_install = Paid_App.groupby(by=Paid_App['Size'])['Installs'].mean().sort_values(ascending = False)

# the most installed top 6 Size
paid_Size_install.head(6)
# Out:
# Size
# 29.000000    2752525.0
# 0.851562     1000000.0
# 94.000000    1000000.0
# 43.000000     750000.0
# 99.000000     550000.0
# 69.000000     550000.0
# Name: Installs, dtype: float64

# %%
# graphical prsentation app which is mostly downloaded by peoples based on the Size

sns.set_style('dark')
plt.rcParams['figure.figsize'] = [20,5]
sns.lineplot(x="Size", y="Installs", color = 'blue', data=Paid_App, size = 10)
plt.ylabel('Installs',fontsize=16)
plt.xlabel('Size(mb)',fontsize=16)
plt.title('Graphical presentation app that people typically download based on size', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
x = np.arange(0, 100, 5)
plt.xticks(x)
plt.xticks(rotation=0);

# %% [markdown]
# **Nearly 2 million paying consumers downloaded apps with sizes between 27 and 30 megabytes, as shown in the following graph. These apps with these sizes performed excellently in stores.**

# %% [markdown]
# ## **8.8 Find the Most using paid apps Android Version ?**

# %%
# find most using paid apps android version 
temp_2= Paid_App[(Paid_App['Android Ver'] != "Varies with device")]
paid_Most_Using_andro_ver = temp_2.groupby(by=temp_2["Android Ver"])['Installs'].mean().sort_values(ascending = False)

# the android verison used by most of the peoples
paid_Most_Using_andro_ver.head()
# Out:
# Android Ver
# 4.1 and up      155737.653061
# 2.3 and up      134054.459016
# 2.0 and up      122020.000000
# 2.3.3 and up    104543.793103
# 3.0 and up       91626.000000
# Name: Installs, dtype: float64

# %%
# graphical prsentation of android verison used by most of the peoples 

sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = [20,5]
sns.pointplot(x="Android Ver", y="Installs", color = 'Red', data=temp_2, size = 10)
plt.ylabel('Installs',fontsize=16)
plt.xlabel('Android Ver',fontsize=16)
plt.title('Android verison used by numbers of Paid Users', fontsize= 20, y=1.05)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **It is preferable to design apps with Android version 4.1 or higher because, according to the above graph, the majority of paying consumers download apps with that version of Android.**

# %% [markdown]
# ## **8.9 Find the Price Range Which is most abfordable by Users ?**

# %%
# find price which most afordable by users ?
Price_install = Paid_App.groupby(by=Paid_App['Price'])['Installs'].mean().sort_values(ascending = False)

# Top 5 price which had high installs 
Price_install
# Out:
# Price
# 6.99     1.012100e+06
# 5.99     1.981143e+05
# 0.99     1.877137e+05
# 13.99    1.000000e+05
# 9.00     1.000000e+05
#              ...
# 39.99    1.000000e+02
# 6.49     1.000000e+02
# 1.76     5.000000e+01
# 1.75     5.000000e+01
# 3.04     1.000000e+01
# Name: Installs, Length: 72, dtype: float64

# %%
# graphical prsentation of price which had high installs

sns.set_style("darkgrid")
plt.rcParamsDefault
p= sns.relplot(x='Price', y='Installs', color="Black", data=Paid_App);
plt.xlabel('Price',fontsize=16)
plt.ylabel('Installs',fontsize=16)
p.fig.suptitle('Price range which highly liked by users', fontsize= 20 , y= 1.06)
x = np.arange(0, 420, 20)
plt.xticks(x)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **Since the majority of paid customers pay between 1 to 13 Doller's to download an app, it is highly recommended to set the pricing of an app between those ranges. The graph above shows that at this rate, applications are downloaded more than 1 million times.**

# %% [markdown]
# # **9. Data Visualization of user_review Dataframe**

# %% [markdown]
# ## **9.1 Percentage of Positive, Negative and Neutral Reviews**

# %%
# Finding Percentage of Positive, Negative and Nutral Reviews

percentage_of_Reviews = pd.DataFrame(index = Df_review['Sentiment'].unique())
percentage_of_Reviews['Percentage'] = (Df_review['Sentiment'].value_counts(normalize=True)*100).round(2)
percentage_of_Reviews
# Out:
#           Percentage
# Negative       22.28
# Neutral        13.50
# Positive       64.22

# %%
# visual presetation Percentage of Positive, Negative and Nutral Reviews

plt.rcParams['figure.figsize'] = [10,10]
labels = 'Negative Reviews','Neutral Reviews','Positive Reviews'
plt.pie(percentage_of_Reviews['Percentage'], labels=labels, explode=[0.01, 0.05, 0.05], shadow=True, autopct='%.2f%%');
plt.title('Percentage of Review Sentiments', fontsize=20);
plt.legend(bbox_to_anchor=(0.9, 1));

# %% [markdown]
# **Based on the above chart, 64% of reviews are positive and 22% are negative; the remaining reviews are regarded as neutral.**

# %% [markdown]
# ## **9.2 Corelate sentiment subjectivity and sentiment polarity**

# %%
# scatterplot for sentiment polarity and sentiment subjectivity

sns.set_style("white")
plt.rcParams['figure.figsize'] = [18,10]
sns.scatterplot(x = 'Sentiment_Subjectivity', y = 'Sentiment_Polarity',hue ='Sentiment', palette="colorblind", data=Df_review )
plt.title("User Reviews Sentiment Analysis", fontsize= 20 , y= 1.06)
plt.tick_params(axis='both' , which='major', labelsize=10)

# %% [markdown]
# **According to the graph above, as sentiment polarity increases, sentiment subjectivity also rises and as subjectivity decreases, polarity also falls.**

# %% [markdown]
# ## **9.3 Catagory with Positive and Negative Reviews**

# %%
Cata_Reviews = Df_review.groupby("Category")['Sentiment'].value_counts().sort_values(ascending=False)
Cata_Reviews.head()
# Out:
# Category            Sentiment
# GAME                Positive     3936
#                     Negative     2408
# HEALTH_AND_FITNESS  Positive     1754
# FAMILY              Positive     1249
# DATING              Positive     1068
# Name: Sentiment, dtype: int64

# %%
sns.set_style("darkgrid")
plt.rcParamsDefault
Df_review.groupby("Category")['Sentiment'].value_counts().unstack().plot.bar(figsize=(25,8), width=2)
plt.xlabel('Category' ,fontsize=16)
plt.ylabel('Num of Reviews',fontsize=16)
plt.title('Number of Review Sentiments in each catagory', fontsize= 20 , y= 1.06)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# **According to the graph above, more than 11k individuals have submitted favourable reviews for games, and more than 7k people have done the same for family and health-and-fitness apps.**

# %% [markdown]
# ## **9.4 Top 10 Positive Reviews Apps**

# %%
Positive_Reviews = Df_review[Df_review['Sentiment']=='Positive']
Positive_Reviews = Positive_Reviews.groupby("App")['Sentiment'].value_counts().sort_values(ascending=False)
Positive_Reviews = Positive_Reviews.head(10)
Positive_Reviews
# Out:
# App                             Sentiment
# Helix Jump                      Positive     209
# Duolingo: Learn Languages Free  Positive     200
# Calorie Counter - Macros        Positive     174
# Calorie Counter - MyFitnessPal  Positive     169
# Bowmasters                      Positive     169
# 10 Best Foods for You           Positive     162
# Google Photos                   Positive     143
# 8fit Workouts & Meal Planner    Positive     137
# Garena Free Fire                Positive     136
# DRAGON BALL LEGENDS             Positive     127
# Name: Sentiment, dtype: int64

# %%
sns.set_style("white")
plt.rcParams['figure.figsize'] = [20,8]
Positive_Reviews.plot(kind='barh', color= '#FEB552')
plt.ylabel('Apps',fontsize=18)
plt.xlabel('Positive Reviews',fontsize=18)
plt.title('Top 10 Apps Positive Review ', fontsize= 20 , y= 1.06)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# ## **9.5 Top 10 Negative Reviews Apps**

# %%
Negative_Reviews = Df_review[Df_review['Sentiment']=='Negative']
Negative_Reviews = Negative_Reviews.groupby("App")['Sentiment'].value_counts().sort_values(ascending=False)
Negative_Reviews = Negative_Reviews.head(10)
Negative_Reviews
# Out:
# App                    Sentiment
# Angry Birds Classic    Negative     147
# Candy Crush Saga       Negative     126
# Bowmasters             Negative     119
# 8 Ball Pool            Negative     106
# Candy Crush Soda Saga  Negative      96
# Garena Free Fire       Negative      81
# Cooking Fever          Negative      79
# Alto's Adventure       Negative      72
# Block Puzzle           Negative      71
# Agar.io                Negative      66
# Name: Sentiment, dtype: int64

# %%
sns.set_style("white")
plt.rcParams['figure.figsize'] = [20,8]
Negative_Reviews.plot(kind='barh', color= '#CC3961')
plt.ylabel('Apps',fontsize=18)
plt.xlabel('Negative Reviews',fontsize=18)
plt.title('Top 10 Apps Negative Review ', fontsize= 20 , y= 1.06)
plt.tick_params(axis='both' , which='major', labelsize=10)
plt.xticks(rotation=90);

# %% [markdown]
# # **CONCLUSION** ✌
#
#
# ###We have analyzed a variety of parameters as part of this study to analyse play store applications that would help AlmaBetter launch their apps successfully. In order to give them the best results from our study, we concentrated more on the problem statements and data cleaning in the initial phase.
#
#
# ##**based on analysis, there is minimal information available regarding the play store datasets**
#
# * 92% of apps are available for free in play store.
#
# * There are 33 categories in the dataset as a whole. The majority of Play Store apps fall under the FAMILY & GAME category.
#
# * Most of the apps in the Google Play store are available to everyone.
#
# * The genres of tools, entertainment, and education make up the great majority of apps in the Google Play Store.
#
# * The majority of apps in the Google Play Store run on Android 4.1 or later.
#
#
# ##**I would advise anyone creating an app for the Playstore to follow these standards.**
#
# ***Category***
# * COMMUNICATION
# * SOCIAL
# * VIDEO PLAYERS
# * ENTERTAINMENT
# * PRODUCTIVITY
#
# **Content Rating**
# * Teen
# * Everyone 10+
#
# ***Geners***
# * Communication
# * Social
# * Video Players & Editors
# * Arcade
# * Adventure; Action & Adventure
#
# ***Size***
#
# Ranging between 70 and 76 (MB)
#
# ***Android versions***
#
# 4.1-7.1.1
#
#
# ##**I would suggest anyone developing a paid app for the Playstore to stick to these requirements.**
#
# ***Category***
# * GAME
# * EDUCATION
# * FAMILY
# * PHOTOGRAPHY
# * WEATHER
#
# ***Content Rating***
# * Mature 17+
# * Everyone 10+
#
# ***Geners***
# * Arcade;Action & Adventure
# * Card;Action & Adventure
# * Action
# * Puzzle;Brain Games
# * Sports;Action & Adventure
#
# ***Size***
#
# Ranging between 0 and 29 (MB)
#
# ***Android versions***
#
# 4.1 and up
#
# ***Price***
#
# 1 to 13 Dollers
#
# ##**Other Findngs**
#
# * App with the smallest size earned the highest ratings
# * The highly reviewed applications has received numerous downloads from users.
# * The majority (64%) of apps in the Google Play store received generally positive reviews.
